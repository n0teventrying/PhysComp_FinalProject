# %%
cota=100
a,b=1,1
while b<= cota:
    a , b = b , a+b
    print('b = ',b)
# Out:
# b =  2
# b =  3
# b =  5
# b =  8
# b =  13
# b =  21
# b =  34
# b =  55
# b =  89
# b =  144

# %%
x , y = 7 , 3
if x < y:
    print(x,' es menor que ',y)
elif x == y:
    pint('Son iguales')
else:
    print(x,' es mayor que ',y)
# Out:
# 7  es mayor que  3

# %%
from pylab import *
# %matplotlib notebook
import math as mt
import numpy as np

# %%
x = linspace(-2*pi,2*pi,50)
y = tan(x)
y[:-1][diff(y)<0]=nan
y1=sin(x)
y2=cos(x)

# %%
#plot(x,y,'.')
#ylim([-2,2])
#show()

# %%
diff(y);#Para buscar el cambio de signo

# %%
diff(y) < 0;

# %%
plot(x,y,label=r'$\tan(x)$')
plot(x,y1,label=r'$\sin(x)$')
plot(x,y2,label=r'$\cos(x)$')
ylim([-2,2]),grid(),legend()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def mi_cos(x,n_max=15):
    y = 0
    x = x%(2*pi)
    for n in range(n_max):
        y += ((-1)**(n))*((x**(2*n))/mt.factorial(2*n))
    return y

# %%
# %%timeit
mi_cos(pi/4)
# Out:
# 7.12 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
cos(pi/4)
# Out:
# 595 ns ± 22.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
t = linspace(0,10*pi)

# %%
4%2
# Out:
# 0

# %%
mi_cos(100*pi)
# Out:
# 1.0

# %%
cos(100*pi)
# Out:
# 1.0
