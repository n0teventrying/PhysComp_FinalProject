# %%
# %run lib_leer_archivos.ipynb
# Out:
# Listo 😀

# %%
mis_datos = leer_archivo_2col('datos_capturados_del_celular.csv')
plot(mis_datos[0,:],mis_datos[1,:])

# %%
mis_datos.shape
# Out:
# (2, 477)

# %%
D_mis_datos = derivar_f_h3(mis_datos[0,:],mis_datos[1,:])

# %%
plot(mis_datos[0,:],D_mis_datos)
show()
