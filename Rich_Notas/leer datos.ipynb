# %% [markdown]
# Nah bro, shit gettin' nasty
# 10 minutes without zaza
# Pues ahorita solo está usando el sensor de luz, pero el mio no hace nada xd
# exporta los datos
# picas tres puntos
# le das en share
# export
# tiempo relativo
# nah bro, lo metio en temporales
# tankiu next diria la chakira
# Nos dio 10 minutos para obtener datos

# %%
from pylab import*
import csv

# %%
todos_los_datos = []
with open('datos_capturados_del_celular.csv') as csvfile:
    datos_leidos = csv.reader(csvfile,delimiter=',')
    for renglon in datos_leidos:
        todos_los_datos.append(renglon)
N_datos = len(todos_los_datos[1:])
datos_numericos = zeros((2,N_datos))
for i in range(N_datos):
    datos_numericos[0,i] = float(todos_los_datos[i+1][0])
    datos_numericos[0,i] = float(todos_los_datos[i+1][1])
plot(datos_numericos[0,:]),datos_numericos[1,:]
show()

# %%
def leer_archivo_2col(nombre_del_archivo,cabeza=1):
    todos_los_datos =[]
    #lectura del archivo y captura de datos
    with open(nombre_del_archivo) as csvfile:
        datos_leidos = csv.reader(csvfile,delimiter=',')
        for renglon in datos_leidos:
            todos_los_datos.append(renglon)
    #acomodar e interpretar datos
    N_datos = len(todos_los_datos[cabeza:])
    datos_numericos = zeros((2,N_datos))
    for i in range(N_datos):
        datos_numericos[0,i] = float(todos_los_datos[i+cabeza][0])
        datos_numericos[1,i] = float(todos_los_datos[i+cabeza][1])
    return datos_numericos

# %%
dat = leer_archivo_2col('datos_capturados_del_celular.csv',100)
plot(dat[0,:],dat[1,:])
show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4720/2648360719.py in <module>
# ----> 1 D_mis_datos = derivar_f_h3(mis_datos[0,:],mis_datos[1,:])
#
# NameError: name 'derivar_f_h3' is not defined
