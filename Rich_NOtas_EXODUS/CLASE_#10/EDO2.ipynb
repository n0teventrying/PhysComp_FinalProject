# %%
from pylab import*

# %%
def mi_Euler(ec_EDO,t,x0, args=[] ,delta=0.1):
    # ec_EDO es el sistema a integrar (t,x)
    # t es el intervalo de integracion
    # x0 punto inicial
    tiempos = arange(t[0],t[1]+delta,delta)
    M, N = len(x0), len(tiempos)
    sol = zeros((M,N))
    sol[:,0] = x0
    for i in range(N-1):
        if len(args)== 0:
            sol[:,i+1] = sol[:,i] + delta*ec_EDO(tiempos[i],sol[:,i])
        else:
            sol[:,i+1] = sol[:,i] + delta*ec_EDO(tiempos[i],sol[:,i],args)
    return sol, tiempos

# %% [markdown]
# $$
# \frac{dy^2}{dt^2} = -y +\cos(2t)
# $$
# con $y(0)=7$ y $y'(0)=0$. La solución es:$y(t) = 7cos(t)$
#
# Hacemos $u = \frac{dy}{dt}$ y por lo tanto $\frac{du}{dt} = \frac{dy^2}{dt^2} = -y +\cos(t)$. Tons
#
# $$
# \frac{dy}{dt}=u\\
# \frac{du}{dt}=-y +\cos(\omega t)
# $$
#
# con condicion incial $(y,u) = (7,0)$

# %%
def ec_dif4(t,y,omega=[1.01]):
    return array([y[1],-y[0]+cos(omega[0]*t)])

# %%
for i in range(9):
    sol,t = mi_Euler(ec_dif4,[0,5*pi],[7,0],[i])
    plot(t,sol[0],label= i) 
legend()
show()

# %%
omegas = arange(0.5,2.5,0.25)
amps = zeros_like(omegas)
for i in range (len(omegas)):
    sol,t = mi_Euler(ec_dif4,[0,20*pi],[7,0],[omegas[i]],0.001)
    plot(t,sol[0],label=omegas[i])
    amps[i] = sol[0].max()
legend()
show()

# %%
omegas = linspace(0.1,2,100)
amps = zeros_like(omegas)
for i in range (len(omegas)):
    sol,t = mi_Euler(ec_dif4,[0,10*pi],[7,0],[omegas[i]],0.001)
    amps[i] = sol[0].max()
plot(omegas,amps)
show()

# %%
def mi_Euler_Jacobi(ec_EDO,t,x0, Jac_EDO, args=[] ,delta=0.1):
    # ec_EDO es el sistema a integrar (t,x)
    # t es el intervalo de integracion
    # x0 punto inicial
    tiempos = arange(t[0],t[1]+delta,delta)
    M, N = len(x0), len(tiempos)
    sol = zeros((M,N))
    sol[:,0] = x0
    for i in range(N-1):
        if len(args)== 0:
            a_Euler = delta*ec_EDO(tiempos[i],sol[:,i])
            a_Jacobi = 0.5*delta*delta*dot(Jac_EDO(tiempos[i],sol[:,i]),ec_EDO(tiempos[i],sol[:,i]))
            sol[:,i+1] = sol[:,i] + a_Euler +a_Jacobi
    return sol, tiempos

# %% [markdown]
# Variables (y,u)
# $$
# \frac{dy}{dt}=u\\
# \frac{du}{dt}=-y
# $$
# La matriz Jacobiana es:
# $$
# \mathbb{J} = \left(\begin{array}{cc}
# 0 & 1\\
# -1 & 1
# \end{array}\right)
# $$

# %%
def ec_dif3(t,y):
    return array([y[1],-y[0]])

def ec_Jac_dif3(t,y):
    return array ([0,1],[-1,0])

# %%
mi_Euler_Jacobi(ec_dif3,[0,4*pi],[7,0],ec_Jac_dif3,delta=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4780/2132726423.py in <module>
# ----> 1 mi_Euler_Jacobi(ec_dif3,[0,4*pi],[7,0],ec_Jac_dif3,delta=0.01)
#
# /tmp/ipykernel_4780/3827260947.py in mi_Euler_Jacobi(ec_EDO, t, x0, Jac_EDO, args, delta)
#      10         if len(args)== 0:
#      11             a_Euler = delta*ec_EDO(tiempos[i],sol[:,i])
# ---> 12             a_Jacobi = 0.5*delta*delta*dot(Jac_EDO(tiempos[i],sol[:,i]),ec_EDO(tiempos[i],sol[:,i]))
#      13             sol[:,i+1] = sol[:,i] + a_Euler +a_Jacobi
#      14         else:
#
# /tmp/ipykernel_4780/965580922.py in ec_Jac_dif3(t, y)
#       3
#       4 def ec_Jac_dif3(t,y):
# ----> 5     return array ([0,1],[-1,0])
#
# TypeError: Field elements must be 2- or 3-tuples, got '-1'

# %%
sol_J,t = mi_Euler_Jacobi(ec_dif4,[0,4*pi],[7,0],ec_Jac_dif3,delta=0.01)
sol_E,t_E = mi_Euler(ec_dif3,[0,4*pi],[7,0],delta=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4780/1319196284.py in <module>
# ----> 1 sol_J,t = mi_Euler_Jacobi(ec_dif4,[0,4*pi],[7,0],ec_Jac_dif3,delta=0.01)
#
# /tmp/ipykernel_4780/3827260947.py in mi_Euler_Jacobi(ec_EDO, t, x0, Jac_EDO, args, delta)
#      10         if len(args)== 0:
#      11             a_Euler = delta*ec_EDO(tiempos[i],sol[:,i])
# ---> 12             a_Jacobi = 0.5*delta*delta*dot(Jac_EDO(tiempos[i],sol[:,i]),ec_EDO(tiempos[i],sol[:,i]))
#      13             sol[:,i+1] = sol[:,i] + a_Euler +a_Jacobi
#      14         else:
#
# /tmp/ipykernel_4780/965580922.py in ec_Jac_dif3(t, y)
#       3
#       4 def ec_Jac_dif3(t,y):
# ----> 5     return array ([0,1],[-1,0])
#
# TypeError: Field elements must be 2- or 3-tuples, got '-1'

# %%
plot(t,sol_J[0],label='E-J')
plot(t,sol_E[0],label='E')
plot(t_J,7*cos(t_J))

# %%
plot(t_J,abs(7*cos(t_J)-sol_j[0]),label='E-J')
plot(t_J,abs(7*cos(t_E)-sol_E[0]),'E')
legend()
show()
